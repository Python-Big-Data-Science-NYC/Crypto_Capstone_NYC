# %%
#https://jessesw.com/Data-Science-Skills/

# %%
from bs4 import BeautifulSoup # For HTML parsing
import urllib2 # Website connections
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = urllib2.urlopen(website).read() # Connect to the job posting
    except: 
        return   # Need this in case the website isn't there anymore or some other weird connection problem 
    
    soup_obj = BeautifulSoup(site) # Get the html from the site
    
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    
    

    text = soup_obj.get_text() # Get the text from this
    
        
    
    lines = (line.strip() for line in text.splitlines()) # break into lines
    
        
        
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    
    def chunk_space(chunk):
        chunk_out = chunk + ' ' # Need to fix spacing issue
        return chunk_out  
        
    
    text = ''.join(chunk_space(chunk) for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
        
        
    # Now clean out all of the unicode junk (this line works great!!!)
        
    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        return                                                         # an exception
       
        
    text = re.sub("[^a-zA-Z.+3]"," ", text)  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                                # Also include + for C++
        
       
    text = text.lower().split()  # Go to lower case and split them apart
        
        
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
        
        
        
    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                            # or not on the website)
        
    return text

# %%
def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = urllib2.urlopen(website).read() # Connect to the job posting
    except: 
        return   # Need this in case the website isn't there anymore or some other weird connection problem 
    
    soup_obj = BeautifulSoup(site) # Get the html from the site
    
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    
    

    text = soup_obj.get_text() # Get the text from this
    
        
    
    lines = (line.strip() for line in text.splitlines()) # break into lines
    
        
        
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    
    def chunk_space(chunk):
        chunk_out = chunk + ' ' # Need to fix spacing issue
        return chunk_out  
        
    
    text = ''.join(chunk_space(chunk) for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
        
        
    # Now clean out all of the unicode junk (this line works great!!!)
        
    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        return                                                         # an exception
       
        
    text = re.sub("[^a-zA-Z.+3]"," ", text)  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                                # Also include + for C++
        
       
    text = text.lower().split()  # Go to lower case and split them apart
        
        
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
        
        
        
    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                            # or not on the website)
        
    return text

# %%
sample = text_cleaner('https://www.indeed.com/job/ux-researcher-0e613ff3bce04c82')
sample[:20] # Just show the first 20 words
# Out:
# C:\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ['roi',
#  'help',
#  'skip',
#  'searchclose',
#  'competitive',
#  'trade',
#  'customer',
#  'relationships.to',
#  'interpersonal',
#  'including',
#  'human',
#  'research.manage',
#  'keywords',
#  'contractsalary',
#  'benefit.consolidate',
#  'find',
#  'wireframes',
#  'impact',
#  'content',
#  'like']

# %%
def skills_info(city = None, state = None):
    '''
    This function will take a desired city/state and look for all new job postings
    on Indeed.com. It will crawl all of the job postings and keep track of how many
    use a preset list of typical data science skills. The final percentage for each skill
    is then displayed at the end of the collation. 
        
    Inputs: The location's city and state. These are optional. If no city/state is input, 
    the function will assume a national search (this can take a while!!!).
    Input the city/state as strings, such as skills_info('Chicago', 'IL').
    Use a two letter abbreviation for the state.
    
    https://www.indeed.com/jobs?q=data+scientist%22&l=san+francisco,+CA  
    
    Output: A bar chart showing the most commonly desired skills in the job market for 
    a data scientist. 
    '''      
    
    
    final_job = 'python' # searching for data scientist exact fit("data scientist" on Indeed search)
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
    if city is not None:
        final_city = city.split() 
        final_city = '+'.join(word for word in final_city)
        final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                    '%2C+', state] # Join all of our strings together so that indeed will search correctly
    else:
        final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

    final_site = ''.join(final_site_list) # Merge the html address together into one string

    
    base_url = 'http://www.indeed.com'
    
    
    try:
        html = urllib2.urlopen(final_site).read() # Open up the front page of our search first
    except:
        'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
        return
    soup = BeautifulSoup(html) # Get the html from the first page
    
    # Now find out how many jobs there were
    
    num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
                                                                        # The 'searchCount' object has this
    
    job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result
    
    print(job_numbers)
    if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
        total_num_jobs = (int(job_numbers[2])*1000) + int(job_numbers[3])
    else:
        total_num_jobs = int(job_numbers[2]) 
    
    city_title = city
    if city is None:
        city_title = 'Nationwide'
        
    print 'There were', total_num_jobs, 'jobs found,', city_title # Display how many jobs were found
    
    num_pages = total_num_jobs/10 # This will be how we know the number of times we need to iterate over each new
                                      # search result page
    job_descriptions = [] # Store all our descriptions in this list
    
    for i in xrange(1,num_pages+1): # Loop through all of our search result pages
        print 'Getting page', i
        start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
        current_page = ''.join([final_site, '&start=', start_num])
        # Now that we can view the correct 10 job returns, start collecting the text samples from each
            
        html_page = urllib2.urlopen(current_page).read() # Get the page
        
        
        page_obj = BeautifulSoup(html_page) # Locate all of the job links
        job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist

        job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs
            
        job_URLS = filter(lambda x:'clk' in x, job_URLS) # Now get just the job related URLS
            
        
        for j in xrange(0,len(job_URLS)):
            final_description = text_cleaner(job_URLS[j])
            if final_description: # So that we only append when the website was accessed correctly
                job_descriptions.append(final_description)
            sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 
        
    print 'Done with collecting the job postings!'    
    print 'There were', len(job_descriptions), 'jobs successfully found.'
    
    
    doc_frequency = Counter() # This will create a full counter of our terms. 
    [doc_frequency.update(item) for item in job_descriptions] # List comp
    
    # Now we can just look at our final dict list inside doc_frequency
    
    # Obtain our key terms and store them in a dict. These are the key data science skills we are looking for
    
    prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                    'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
                    'Ruby':doc_frequency['ruby'],
                    'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
                    'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})
                      
    analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                        'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                        'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

    hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
                'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
                'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
                'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
                'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})
                
    database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
                    'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
                    'MongoDB':doc_frequency['mongodb']})
                     
               
    overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
    
        
    
    final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
                                                                                                # dataframe 
    
    # Change the values to reflect a percentage of the postings 
    
    final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                                    #  having that term 
    
    # Sort the data for plotting purposes
    
    final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)
    
    # Get it ready for a bar plot
        
    final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
                            title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)
        
    final_plot.set_ylabel('Percentage Appearing in Job Ads')
    fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object
        
        
    return fig, final_frame # End of the function

# %%
silicon_val_info = skills_info(city = 'San Francisco', state = 'CA')
# Out:
# ['1', '3', '978']
# There were 978 jobs found, San Francisco
# Getting page 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-63d4c6ba5e4e> in <module>()
# ----> 1 silicon_val_info = skills_info(city = 'San Francisco', state = 'CA')
#
# <ipython-input-5-9158c40da38e> in skills_info(city, state)
#      77         job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
#      78
# ---> 79         job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs
#      80
#      81         job_URLS = filter(lambda x:'clk' in x, job_URLS) # Now get just the job related URLS
#
# TypeError: cannot concatenate 'str' and 'NoneType' objects

# %%
city, state = "San Francisco", 'CA'
'''
This function will take a desired city/state and look for all new job postings
on Indeed.com. It will crawl all of the job postings and keep track of how many
use a preset list of typical data science skills. The final percentage for each skill
is then displayed at the end of the collation. 

Inputs: The location's city and state. These are optional. If no city/state is input, 
the function will assume a national search (this can take a while!!!).
Input the city/state as strings, such as skills_info('Chicago', 'IL').
Use a two letter abbreviation for the state.

https://www.indeed.com/jobs?q=data+scientist%22&l=san+francisco,+CA  

Output: A bar chart showing the most commonly desired skills in the job market for 
a data scientist. 
'''      

#data+scientist+
final_job = 'python' # searching for data scientist exact fit("data scientist" on Indeed search)

# Make sure the city specified works properly if it has more than one word (such as San Francisco)
if city is not None:
    final_city = city.split() 
    final_city = '+'.join(word for word in final_city)
    final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                '%2C+', state] # Join all of our strings together so that indeed will search correctly
else:
    final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

final_site = ''.join(final_site_list) # Merge the html address together into one string


base_url = 'http://www.indeed.com'


try:
    html = urllib2.urlopen(final_site).read() # Open up the front page of our search first
except:
    'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
#     return
soup = BeautifulSoup(html) # Get the html from the first page

# Now find out how many jobs there were

num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
                                                                    # The 'searchCount' object has this

job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result

print('hello')
print(job_numbers[1]+job_numbers[2])
job_numbers[1] = job_numbers[1]+job_numbers[2]

if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
    total_num_jobs = (int(job_numbers[2])*1000) + int(job_numbers[3])
else:
    total_num_jobs = int(job_numbers[1]) 

city_title = city
if city is None:
    city_title = 'Nationwide'

print 'There were', total_num_jobs, 'jobs found,', city_title # Display how many jobs were found

num_pages = total_num_jobs/10 # This will be how we know the number of times we need to iterate over each new
                                  # search result page
job_descriptions = [] # Store all our descriptions in this list

print(num_pages, "number of pages")

for i in xrange(1,num_pages+1): # Loop through all of our search result pages
    print 'Getting page', i
    start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
    current_page = ''.join([final_site, '&start=', start_num])
    # Now that we can view the correct 10 job returns, start collecting the text samples from each
    sleep(5)
    print (current_page, "current page")
    print ("Oyeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee")
    
    html_page = urllib2.urlopen(current_page).read() # Get the page

    page_obj = BeautifulSoup(html_page) # Locate all of the job links
    job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
    print ("job_link_area")
    #print (job_link_area)
    
    print ((link.get('href') for link in job_link_area.find_all('a')))
    print (base_url, "base_url")
    # This thing no longer exists
    
    #job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs

    #job_URLS = filter(lambda x:'clk' in x, job_URLS) # Now get just the job related URLS
   # print job_URLS

#     for j in xrange(0,len(job_URLS)):
#         final_description = text_cleaner(job_URLS[j])
#         if final_description: # So that we only append when the website was accessed correctly
#             job_descriptions.append(final_description)
#         sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 

print 'Done with collecting the job postings!'    
print 'There were', len(job_descriptions), 'jobs successfully found.'


doc_frequency = Counter() # This will create a full counter of our terms. 
[doc_frequency.update(item) for item in job_descriptions] # List comp

# Now we can just look at our final dict list inside doc_frequency

# Obtain our key terms and store them in a dict. These are the key data science skills we are looking for

prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
                'Ruby':doc_frequency['ruby'],
                'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
                'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})

analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                    'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                    'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
            'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
            'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
            'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
            'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})

database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
                'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
                'MongoDB':doc_frequency['mongodb']})


overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects



final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
                                                                                            # dataframe 

# Change the values to reflect a percentage of the postings 

final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                                #  having that term 

# Sort the data for plotting purposes

#final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)

# Get it ready for a bar plot

#final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
 #                       title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)

#final_plot.set_ylabel('Percentage Appearing in Job Ads')
#fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object


#return fig, final_frame # End of the function
# Out:
# hello
# 3981
# There were 3981 jobs found, San Francisco
# (398, 'number of pages')
# Getting page 1
# ('http://www.indeed.com/jobs?q=%22python%22&l=San+Francisco%2C+CA&start=10', 'current page')
# Oyeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# job_link_area
# <generator object <genexpr> at 0x000000000E5A98B8>
# ('http://www.indeed.com', 'base_url')
# Getting page 2
# ('http://www.indeed.com/jobs?q=%22python%22&l=San+Francisco%2C+CA&start=20', 'current page')
# Oyeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# job_link_area
# <generator object <genexpr> at 0x000000000CF468B8>
# ('http://www.indeed.com', 'base_url')
# Getting page 3
# ('http://www.indeed.com/jobs?q=%22python%22&l=San+Francisco%2C+CA&start=30', 'current page')
# Oyeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# job_link_area
# <generator object <genexpr> at 0x000000000DFE3F30>
# ('http://www.indeed.com', 'base_url')
# Getting page 4
# ('http://www.indeed.com/jobs?q=%22python%22&l=San+Francisco%2C+CA&start=40', 'current page')
# Oyeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# job_link_area
# <generator object <genexpr> at 0x000000000D9286C0>
# ('http://www.indeed.com', 'base_url')
# Getting page 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-736126d3f320> in <module>()
#      75     current_page = ''.join([final_site, '&start=', start_num])
#      76     # Now that we can view the correct 10 job returns, start collecting the text samples from each
# ---> 77     sleep(5)
#      78     print (current_page, "current page")
#      79     print ("Oyeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee")
#
# KeyboardInterrupt:

# %%
site = urllib2.urlopen('https://www.indeed.com/jobs?q=%22python%22&l=San%20Francisco,%20CA&start=30').read() # Connect to the job posting
soup = BeautifulSoup(site) # Get the html from the site
for div in soup.find_all('div',attrs={"class" : "jobtitle turnstileLink"}):
    print div#text[div.text]

# %%
import urllib2
from bs4 import BeautifulSoup

URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

soup = BeautifulSoup(urllib2.urlopen(URL).read(), 'html.parser')

results = soup.find_all('div', attrs={'data-tn-component': 'organicJob'})

#print results

for x in results:
    company = x.find('span', attrs={"class":"summary"})
    print 'company:', company.text.strip()

    company = x.find('span', attrs={"class":"location"})
    print 'company:', company.text.strip()
    
    job = x.find('a', attrs={'data-tn-element': "jobTitle"})
    print 'job:', job.text.strip()

    salary = x.find('nobr')
    if salary:
        print 'salary:', salary.text.strip()

    print '----------'
# Out:
# company: HelloFresh is seeking a Data Scientist to help spearhead our personalization initiative. Promote a data smart and data aware culture within a large...
# company: New York, NY
# job: Data Scientist, Personalization
# ----------
# company: Director of Data Science*. Identify patterns in large data sets. Ability to lead and manage a team of scientists....
# company: New York, NY
# job: Director of Data Science
# ----------
# company: Research Data Analyst. The Educational research data analyst reports to the Educational Director and focuses on compiling survey data, producing statistical...
# company: New York State
# job: Research Data Analyst
# ----------
# company: About the Data Scientist position. Pluvio is a data driven tech company looking for an experienced Lead Data Scientist to help us scale our data science team....
# company: New York State
# job: Data Science Engineer
# ----------
# company: 3+ years professional experience with data engineering, data science, and/or database administration. We are looking for an experienced data engineer/scientist...
# company: New York, NY
# job: Data Scientist
# ----------
# company: Minimum four (4) years of experience in data analytics, data modeling and data sciences. Minimum six (6) years of experience with SAS, R, Python, Alteryx, and...
# company: New York, NY
# job: Data Scientist
# ----------
# company: Create data table transformations, perform data validation. Analyze large data sets. Data Scientist's (DS’s) create answers to client-driven business problems...
# company: New York, NY 10022 (Midtown area)
# job: Data Scientist - Jr. / Mid Level
# ----------
# company: As a Data Scientist at MealPal, you will focus on using data to drive business strategy and take our company to the next level....
# company: New York, NY
# job: Data Scientist
# ----------
# company: Experience in applying data science methods to business problems. MSc or PhD in Machine Learning, Applied Statistics, Biostatistics, Data Science....
# company: New York, NY 10022 (Midtown area)
# job: Data Scientist - Healthcare Analytics & Delivery, Advanced A...
# ----------
# company: Data Quality checks / Deep Dives. Linking data sets to generate reports. Developing new applications / uses for the existing data....
# company: New York, NY
# job: Data Scientist/Consultant
# ----------

# %%
import urllib2
from bs4 import BeautifulSoup

data =[]

city, state = "New York", 'NY'
    

#data+scientist+
final_job = 'python' # searching for data scientist exact fit("data scientist" on Indeed search)

# Make sure the city specified works properly if it has more than one word (such as San Francisco)
if city is not None:
    final_city = city.split() 
    final_city = '+'.join(word for word in final_city)
    final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                '%2C+', state] # Join all of our strings together so that indeed will search correctly
else:
    final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

final_site = ''.join(final_site_list) # Merge the html address together into one string

base_url = 'http://www.indeed.com'

try:
    html = urllib2.urlopen(final_site).read() # Open up the front page of our search first
except:
    'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
#     return
soup = BeautifulSoup(html) # Get the html from the first page

# Now find out how many jobs there were

num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
                                                                    # The 'searchCount' object has this

job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result

print('hello')
print(job_numbers[1]+job_numbers[2])
job_numbers[1] = job_numbers[1]+job_numbers[2]

if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
    total_num_jobs = (int(job_numbers[2])*1000) + int(job_numbers[3])
else:
    total_num_jobs = int(job_numbers[1]) 

city_title = city
if city is None:
    city_title = 'Nationwide'

print 'There were', total_num_jobs, 'jobs found,', city_title # Display how many jobs were found

num_pages = total_num_jobs/10 # This will be how we know the number of times we need to iterate over each new
                                  # search result page
job_descriptions = [] # Store all our descriptions in this list

print(num_pages, "number of pages")


for i in xrange(1,num_pages+1): # Loop through all of our search result pages
    print 'Getting page', i
    start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
    current_page = ''.join([final_site, '&start=', start_num])
    # Now that we can view the correct 10 job returns, start collecting the text samples from each
    sleep(5)
    print (current_page, "current page")


    URL = current_page #"http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

    soup = BeautifulSoup(urllib2.urlopen(URL).read(), 'html.parser')

    results = soup.find_all('div', attrs={'data-tn-component': 'organicJob'})

    #print results

    for x in results:
        company = x.find('span', attrs={"class":"summary"})
        #print 'company:', company.text.strip()

        location = x.find('span', attrs={"class":"location"})
        #print 'company:', location.text.strip()

        job = x.find('a', attrs={'data-tn-element': "jobTitle"})
        #print 'job:', job.text.strip()

        data.append([company.text.strip(),location.text.strip(),job.text.strip()])
        
        print (data)
        print '----------'
# Out:
# hello
# 4745
# There were 4745 jobs found, New York
# (474, 'number of pages')
# Getting page 1
# ('http://www.indeed.com/jobs?q=%22python%22&l=New+York%2C+NY&start=10', 'current page')
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend']]
# ----------
# Getting page 2
# ('http://www.indeed.com/jobs?q=%22python%22&l=New+York%2C+NY&start=20', 'current page')
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst'], [u'At L2, our current tech stack includes Python, PostgreSQL, Redshift, AWS, and Docker. We are looking for a junior to mid-level Full Stack Developer with a...', u'New York, NY', u'Junior Full Stack Developer, Gartner Research & Advisory']]
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst'], [u'At L2, our current tech stack includes Python, PostgreSQL, Redshift, AWS, and Docker. We are looking for a junior to mid-level Full Stack Developer with a...', u'New York, NY', u'Junior Full Stack Developer, Gartner Research & Advisory'], [u"Python, VBA, C#, Matlab, SQL. Cr\xe9dit Agricole CIB is the Corporate and Investment Banking arm of the Cr\xe9dit Agricole Group, the world's n\xb013 bank measured by...", u'New York, NY', u'Quantitative Analyst']]
# ----------
# Getting page 3
# ('http://www.indeed.com/jobs?q=%22python%22&l=New+York%2C+NY&start=30', 'current page')
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst'], [u'At L2, our current tech stack includes Python, PostgreSQL, Redshift, AWS, and Docker. We are looking for a junior to mid-level Full Stack Developer with a...', u'New York, NY', u'Junior Full Stack Developer, Gartner Research & Advisory'], [u"Python, VBA, C#, Matlab, SQL. Cr\xe9dit Agricole CIB is the Corporate and Investment Banking arm of the Cr\xe9dit Agricole Group, the world's n\xb013 bank measured by...", u'New York, NY', u'Quantitative Analyst'],  ...
# ----------
# ...
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst'], [u'At L2, our current tech stack includes Python, PostgreSQL, Redshift, AWS, and Docker. We are looking for a junior to mid-level Full Stack Developer with a...', u'New York, NY', u'Junior Full Stack Developer, Gartner Research & Advisory'], [u"Python, VBA, C#, Matlab, SQL. Cr\xe9dit Agricole CIB is the Corporate and Investment Banking arm of the Cr\xe9dit Agricole Group, the world's n\xb013 bank measured by...", u'New York, NY', u'Quantitative Analyst'],  ...
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst'], [u'At L2, our current tech stack includes Python, PostgreSQL, Redshift, AWS, and Docker. We are looking for a junior to mid-level Full Stack Developer with a...', u'New York, NY', u'Junior Full Stack Developer, Gartner Research & Advisory'], [u"Python, VBA, C#, Matlab, SQL. Cr\xe9dit Agricole CIB is the Corporate and Investment Banking arm of the Cr\xe9dit Agricole Group, the world's n\xb013 bank measured by...", u'New York, NY', u'Quantitative Analyst'],  ...
# ----------
# [[u'Expert in Python. Contribute to the design and development of python data workflow management platform....', u'New York, NY 10152 (Midtown area)', u'Data Engineer (Python)'], [u'Full Stack Python Developer Intern. You are experienced in building applications using Python, HTML, CSS, JS and jQuery....', u'New York, NY', u'Full Stack Python Developer Intern'], [u'Excellent computational data engineering know-how with complete fluency with Python and SQL. Extraordinary Internship Opportunity....', u'New York, NY', u'Data Science Internship'], [u'Java, Python, C++ or Groovy is a prerequisite. We are seeking a creative and research-minded portfolio analyst to join one of our growing Quantitative...', u'New York, NY', u'Portfolio Research Analyst'], [u'You write great Python. Packaging techniques as reusable modules written in python, using spaCy as the foundation....', u'New York, NY', u'Data Science Intern'], [u'We prefer experience with JavaScript or Python, but will consider candidates versed in other programming languages. About the Position*....', u'New York, NY', u'Software Programmer'], [u'Python needs to be upgraded from 2.5.2 to the current 3.5.3 version. Fluent in Python and Django, experience with several versions of these languages, ideally...', u'New York, NY', u'Python Developer'], [u'I.T. Support Assistants support routine operations and problem resolution of computing and/or communications functions at a College or Unit. They work in...', u'New York, NY', u'Junior System Support Engineer IT Support- Hourly'], [u'We are looking for a Marketing Analytics professional. This person will touch all aspects of the organization including marketing, product, and engineering to...', u'New York, NY', u'Marketing Data Analyst'], [u'Python or Shell Scripting language familiarity. We are looking for a talented backend engineer with an interest in networking, iot and video programming in...', u'New York, NY', u'Software Engineer - Backend'], [u'The ideal candidate will have significant experience with web development, ETL process, database architecture and a solid understanding of data processing using...', u'Lyndhurst, NJ 07071', u'Python Developer'], [u'Must have hands on experience in Python. 8 + years of Total IT Experience with good experience and exposure in Python. JD:....', u'New York, NY', u'Python Developer'], [u'Solid experience and knowledge in Python development and concepts. We are seeking a Python developer with experience in investment banking for a leading banking...', u'New York, NY', u'Python Developer'], [u'We are looking for talented and ambitious engineers to join our tight-knit team. You will work closely with our chief of technology as well as our growth,...', u'New York, NY 10038 (Financial District area)', u'Python Developer'], [u'Accomplished in a general purpose programming language such Python or Java with the ability to learn other languages as needed....', u'New York, NY 10022 (Midtown area)', u'Quantitative Analyst'], [u'Skills in Python and/or R. HeartRadio, iHeartMedia\u2019s digital radio platform, is the No....', u'New York, NY', u'Data Analyst'], [u'Technical experience with SQL, UNIX, and Python a plus. Financial Data is responsible for back office pricing as well as time series data for trading/modeling...', u'New York, NY', u'Data Analyst'], [u'About Rent the Runway: Rent the Runway is disrupting the $1.7 trillion global fashion industry by introducing clothing rental as a utility in women\u2019s...', u'New York, NY', u'Data Analyst'], [u'At L2, our current tech stack includes Python, PostgreSQL, Redshift, AWS, and Docker. We are looking for a junior to mid-level Full Stack Developer with a...', u'New York, NY', u'Junior Full Stack Developer, Gartner Research & Advisory'], [u"Python, VBA, C#, Matlab, SQL. Cr\xe9dit Agricole CIB is the Corporate and Investment Banking arm of the Cr\xe9dit Agricole Group, the world's n\xb013 bank measured by...", u'New York, NY', u'Quantitative Analyst'],  ...
# ----------
# Getting page 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-d7a5f0f552cd> in <module>()
#      64     current_page = ''.join([final_site, '&start=', start_num])
#      65     # Now that we can view the correct 10 job returns, start collecting the text samples from each
# ---> 66     sleep(5)
#      67     print (current_page, "current page")
#      68
#
# KeyboardInterrupt:

# %%
import pandas as pd

data

labels = ['Company', 'Location', 'Role']
df = pd.DataFrame.from_records(data, columns=labels)

df
# Out:
#                                               Company  \
# 0   Expert in Python. Contribute to the design and...
# 1   Full Stack Python Developer Intern. You are ex...
# 2   Excellent computational data engineering know-...
# 3   Java, Python, C++ or Groovy is a prerequisite....
# 4   You write great Python. Packaging techniques a...
# 5   We prefer experience with JavaScript or Python...
# 6   Python needs to be upgraded from 2.5.2 to the ...
# 7   I.T. Support Assistants support routine operat...
# 8   We are looking for a Marketing Analytics profe...
# 9   Python or Shell Scripting language familiarity...
# 10  The ideal candidate will have significant expe...
# 11  Must have hands on experience in Python. 8 + y...
# 12  Solid experience and knowledge in Python devel...
# 13  We are looking for talented and ambitious engi...
# 14  Accomplished in a general purpose programming ...
# 15  Skills in Python and/or R. HeartRadio, iHeartM...
# 16  Technical experience with SQL, UNIX, and Pytho...
# 17  About Rent the Runway: Rent the Runway is disr...
# 18  At L2, our current tech stack includes Python,...
# 19  Python, VBA, C#, Matlab, SQL. Crédit Agricole ...
# 20  Python, VBA, C#, Matlab, SQL. Crédit Agricole ...
# 21  Comfortable coding in Python and JavaScript; P...
# 22  Strong programming skills in Python or similar...
# 23  Create Python services on Linux. 3+ years of p...
# 24  C (Kernel), C++, Python, Perl, Linux, UNIX, BA...
# 25  JavaScript, Perl, Python) to build interactive...
# 26  You can work with data in a language such as P...
# 27  You have at least 2 years of development exper...
# 28  Competency with Python, preferably including r...
# 29  Programming experience, preferably in R and Py...
# ..                                                ...
# 50  Under the direction of the Assistant Commissio...
# 51  Lean to use Tableau, SQL, and Python. The Puls...
# 52  Ensure all Python and Javascript code is suita...
# 53  Modeling experience in python, or programming ...
# 54  Strong level in python. Develop Python scripts...
# 55  Strong level in python. Develop Python scripts...
# 56  Python, Java, C++, C#, Ruby). We are looking f...
# 57  MORE ABOUT THIS JOB CONSUMER AND COMMERCIAL BA...
# 58  Proficiency in one or more general purpose pro...
# 59  Proficiency with systems such as SQL, Python, ...
# 60  Python, Java, Ruby, JavaScript, Perl, C/C++). ...
# 61  Work closely with the Quant team to develop pr...
# 62  REQUIRED QUALIFICATIONS Skill Set Required: Te...
# 63  REQUIRED QUALIFICATIONS Skill Set Required: Te...
# 64  Experience with Python, PHP, Javascript (Node)...
# 65  PYTHON programming, Athena and / or SecDb / Sl...
# 66  Expertise in Excel, databases, and SQL (knowle...
# 67  Python or Scala experience a plus. Kasisto, a ...
# 68  Minimum six (6) years of experience with SAS, ...
# 69  MORE ABOUT THIS JOB Associate-Research with Go...
# 70  Must script in Python, Perl, Shell, or other r...
# 71  HTML, CSS, Javascript, Python 1/2, Angular 1/2...
# 72  Experience with at least one scripting languag...
# 73  Proficiency with Excel, Python, DFP, Ad Exchan...
# 74  VaynerMedia is a digital agency that helps For...
# 75  Experience with tools development using QT, py...
# 76  Skilled in LUA, python, QT or wxWidgets To app...
# 77  What You’ll do: Perform data exploration, stat...
# 78  The Department of Biomedical Informatics at Co...
# 79  Work on Hydrogen Python API with team of softw...
#
#                                         Location  \
# 0              New York, NY 10152 (Midtown area)
# 1                                   New York, NY
# 2                                   New York, NY
# 3                                   New York, NY
# 4                                   New York, NY
# 5                                   New York, NY
# 6                                   New York, NY
# 7                                   New York, NY
# 8                                   New York, NY
# 9                                   New York, NY
# 10                           Lyndhurst, NJ 07071
# 11                                  New York, NY
# 12                                  New York, NY
# 13  New York, NY 10038 (Financial District area)
# 14             New York, NY 10022 (Midtown area)
# 15                                  New York, NY
# 16                                  New York, NY
# 17                                  New York, NY
# 18                                  New York, NY
# 19                                  New York, NY
# 20                                  New York, NY
# 21                                  New York, NY
# 22                                  New York, NY
# 23                                  New York, NY
# 24                                  New York, NY
# 25                                  New York, NY
# 26                                  New York, NY
# 27                                  New York, NY
# 28     New York, NY 10028 (Upper East Side area)
# 29                                  New York, NY
# ..                                           ...
# 50                                    Queens, NY
# 51                                  New York, NY
# 52                                  Brooklyn, NY
# 53                                  New York, NY
# 54                                  New York, NY
# 55                                  New York, NY
# 56                                  New York, NY
# 57             New York, NY 10282 (Tribeca area)
# 58             New York, NY 10179 (Midtown area)
# 59                                  New York, NY
# 60                                  New York, NY
# 61             New York, NY 10179 (Midtown area)
# 62                                  New York, NY
# 63                                  New York, NY
# 64                                  New York, NY
# 65                                  New York, NY
# 66                                  New York, NY
# 67                                  New York, NY
# 68                                  New York, NY
# 69             New York, NY 10282 (Tribeca area)
# 70             New York, NY 10017 (Midtown area)
# 71             New York, NY 10017 (Midtown area)
# 72                                  New York, NY
# 73                                  New York, NY
# 74                                  New York, NY
# 75                                  New York, NY
# 76                                  New York, NY
# 77        New York, NY 10281 (Battery Park area)
# 78                                  New York, NY
# 79                                  New York, NY
#
#                                                  Role
# 0                              Data Engineer (Python)
# 1                  Full Stack Python Developer Intern
# 2                             Data Science Internship
# 3                          Portfolio Research Analyst
# 4                                 Data Science Intern
# 5                                 Software Programmer
# 6                                    Python Developer
# 7   Junior System Support Engineer IT Support- Hourly
# 8                              Marketing Data Analyst
# 9                         Software Engineer - Backend
# 10                                   Python Developer
# 11                                   Python Developer
# 12                                   Python Developer
# 13                                   Python Developer
# 14                               Quantitative Analyst
# 15                                       Data Analyst
# 16                                       Data Analyst
# 17                                       Data Analyst
# 18  Junior Full Stack Developer, Gartner Research ...
# 19                               Quantitative Analyst
# 20                               Quantitative Analyst
# 21           Data Analyst - NoSQL, Python, JavaScript
# 22                       Information Security Analyst
# 23  Senior Full Stack Web Engineer- Enterprise Sol...
# 24                                Software Programmer
# 25                                   Platform Analyst
# 26                            Front-line Data Analyst
# 27                        Software Developer - Python
# 28                           Paid Research Internship
# 29             Research Analyst – Junior Statistician
# ..                                                ...
# 50                                       Data Analyst
# 51                                   Analytics Intern
# 52  Full Stack Developer (Python / Django) - Backs...
# 53                                Data Science Intern
# 54                   Python Developer Risk Management
# 55                   Python Developer Risk Management
# 56                              Data Scientist Intern
# 57                                     Data Scientist
# 58                       Python/C++ Software Engineer
# 59                             Associate Data Analyst
# 60                                       Data Analyst
# 61         Python Software Engineer for Credit Athena
# 62                       Python Support and Developer
# 63                       Python Support and Developer
# 64                                 Junior QA Engineer
# 65  Sr. Developer (Python, Athena, SecDB, Slang, F...
# 66                             BI & Reporting Analyst
# 67                                     Data Scientist
# 68                                     Data Scientist
# 69               Associate-Research - SEC102317LYFICC
# 70        Trade Ops & FX Apps Engineer - FIX - Python
# 71                      Full Stack Engineering Intern
# 72                                   Business Analyst
# 73                                      Yield Analyst
# 74                        Analyst, Data and Analytics
# 75                                      AI Programmer
# 76                                Gameplay Programmer
# 77                                       Data Analyst
# 78                     Software Developer (Part-Time)
# 79                  Senior Software Engineer - Python
#
# [80 rows x 3 columns]
